# %% [markdown]
# # Heart Disease EDA Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

df = pd.read_csv(Path('..') / 'dataset' / 'heart.csv')
df.head()
